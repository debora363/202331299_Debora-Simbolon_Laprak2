# %% [markdown]
# # Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Membaca Data Gambar

# %%
img = cv2.imread('img_mobil.jpg')

# %%
img.shape
# Out:
# (500, 800, 3)

# %%
[baris, kolom] = img.shape[:2]

# %% [markdown]
# # Convert BGR to RGB

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Menampilkan Histogram

# %%
fig, axs = plt.subplots(2,2,figsize=(15,5))

#cara1
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])

#cara2
hist = cv2.calcHist([rgb],[0],None,[256],[0,256])
axs[1,0].imshow(rgb)
axs[1,1].plot(hist)

#menampilkan 
plt.show()
# Out:
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\348090450.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])

# %% [markdown]
# # Oprasi Piksel untuk meningkatkan Kecerahan

# %%
beta = 40
citra_cerah = np.zeros((baris, kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx = rgb[x,y] + beta
        citra_cerah[x,y] = gyx
        
citra_cerah = citra_cerah.astype(np.uint8)

fig, axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_cerah)
axs[1,1].hist(citra_cerah.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\2905638638.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\2905638638.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_cerah.ravel(),256,[0,256])

# %% [markdown]
# # Meregangkan Kontras

# %%
alpha = 1.2
citra_kontras = np.zeros((baris, kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx = rgb[x,y] * alpha
        citra_kontras[x,y] = gyx
        
citra_kontras = citra_kontras.astype(np.uint8)

fig, axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_kontras)
axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\2133194377.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\2133194377.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

# %% [markdown]
# # Operasi

# %%
beta = 10 
alpha = 1.2
citra_kontras = np.zeros((baris, kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx = alpha * rgb[x,y] + beta
        citra_kontras[x,y] = gyx
        
citra_kontras = citra_kontras.astype(np.uint8)

fig, axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_kontras)
axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\1891866572.py:14: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\1891866572.py:16: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

# %% [markdown]
# # Membalik Citra

# %%
citra_negatif = np.zeros((baris, kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx = 255 - rgb[x,y]
        citra_negatif[x,y] = gyx
        
citra_negatif = citra_negatif.astype(np.uint8)

fig, axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_negatif)
axs[1,1].hist(citra_negatif.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\3808766078.py:12: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\debor\AppData\Local\Temp\ipykernel_1492\3808766078.py:14: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_negatif.ravel(),256,[0,256])

# %% [markdown]
# # 202331299
# # Debora Simbolon
